# %%
import pandas as pd

# %%
dfp = pd.read_csv('data/player_data.csv') 
dfp.tail()
# Out:
#              name  year_start  year_end position height  weight  \
# 4545   Ante Zizic        2018      2018      F-C   6-11   250.0
# 4546     Jim Zoet        1983      1983        C    7-1   240.0
# 4547    Bill Zopf        1971      1971        G    6-1   170.0
# 4548  Ivica Zubac        2017      2018        C    7-1   265.0
# 4549   Matt Zunic        1949      1949      G-F    6-3   195.0
#
#              birth_date                       college
# 4545    January 4, 1997                           NaN
# 4546  December 20, 1953         Kent State University
# 4547       June 7, 1948           Duquesne University
# 4548     March 18, 1997                           NaN
# 4549  December 19, 1919  George Washington University

# %%
dfs = pd.read_csv('data/Seasons_Stats.csv', index_col = 0)
dfs.tail()
# Out:
#          Year             Player Pos   Age   Tm     G    GS      MP   PER  \
# 24686  2017.0        Cody Zeller  PF  24.0  CHO  62.0  58.0  1725.0  16.7
# 24687  2017.0       Tyler Zeller   C  27.0  BOS  51.0   5.0   525.0  13.0
# 24688  2017.0  Stephen Zimmerman   C  20.0  ORL  19.0   0.0   108.0   7.3
# 24689  2017.0        Paul Zipser  SF  22.0  CHI  44.0  18.0   843.0   6.9
# 24690  2017.0        Ivica Zubac   C  19.0  LAL  38.0  11.0   609.0  17.0
#
#          TS%  ...    FT%    ORB    DRB    TRB   AST   STL   BLK   TOV     PF  \
# 24686  0.604  ...  0.679  135.0  270.0  405.0  99.0  62.0  58.0  65.0  189.0
# 24687  0.508  ...  0.564   43.0   81.0  124.0  42.0   7.0  21.0  20.0   61.0
# 24688  0.346  ...  0.600   11.0   24.0   35.0   4.0   2.0   5.0   3.0   17.0
# 24689  0.503  ...  0.775   15.0  110.0  125.0  36.0  15.0  16.0  40.0   78.0
# 24690  0.547  ...  0.653   41.0  118.0  159.0  30.0  14.0  33.0  30.0   66.0
#
#          PTS
# 24686  639.0
# 24687  178.0
# 24688   23.0
# ...

# %%
players_studied = ['Kevin Durant', 'Dwyane Wade', 'Tim Duncan', "Shaquille O'Neal", 'Allen Iverson', 'Ray Allen', 'Paul Pierce', 'Vince Carter', 'Kobe Bryant', 'LeBron James', 'Lou Williams', 'Vlade Divac', "Jermaine O'Neal", "Amar'e Stoudemire", 'Tracy McGrady', 'Kevin Garnett', 'James Harden']
yearInNBA = {}

# %%
mydf = dfs[dfs.Player.isin(players_studied)]
mydf
# Out:
#          Year             Player Pos   Age   Tm     G    GS      MP   PER  \
# 9637   1990.0        Vlade Divac   C  21.0  LAL  82.0   5.0  1611.0  17.5
# 10106  1991.0        Vlade Divac   C  22.0  LAL  82.0  81.0  2310.0  17.7
# 10559  1992.0        Vlade Divac   C  23.0  LAL  36.0  18.0   979.0  15.9
# 11012  1993.0        Vlade Divac   C  24.0  LAL  82.0  69.0  2525.0  17.1
# 11477  1994.0        Vlade Divac   C  25.0  LAL  79.0  73.0  2685.0  18.8
# 11939  1995.0        Vlade Divac   C  26.0  LAL  80.0  80.0  2807.0  20.5
# 12408  1996.0        Vlade Divac   C  27.0  LAL  79.0  79.0  2470.0  17.4
# 12448  1996.0      Kevin Garnett  SF  19.0  MIN  80.0  43.0  2293.0  15.8
# 12846  1997.0          Ray Allen  SG  21.0  MIL  82.0  81.0  2532.0  14.6
# 12900  1997.0        Kobe Bryant  SG  18.0  LAL  71.0   6.0  1103.0  14.4
# 12969  1997.0        Vlade Divac   C  28.0  CHH  81.0  80.0  2840.0  17.9
# 13012  1997.0      Kevin Garnett  SF  20.0  MIN  77.0  77.0  2995.0  18.2
# ...

# %%
dfp[dfp.name.isin(players_studied)].year_start.astype(float)
# Out:
# 58      1997.0
# 528     1997.0
# 649     1999.0
# 1018    1990.0
# 1078    1998.0
# 1085    2008.0
# 1370    1996.0
# 1627    2010.0
# 1904    1997.0
# 1952    2004.0
# 2652    1998.0
# 3013    1997.0
# 3014    1993.0
# 3201    1999.0
# 3877    2003.0
# 4167    2004.0
# 4391    2006.0
# Name: year_start, dtype: float64

# %%
float(dfp[dfp.name == player].year_start)
# Out:
# 2006.0

# %%
values = {}
for player in players_studied:
    print(player)
    print(mydf[mydf.Player == player].Year - float(dfp[dfp.name == player].year_start))
# Out:
# Kevin Durant
# 18894    0.0
# 19506    1.0
# 20071    2.0
# 20684    3.0
# 21264    4.0
# 21827    5.0
# 22438    6.0
# 23040    7.0
# 23654    8.0
# 24239    9.0
# Name: Year, dtype: float64
# Dwyane Wade
# 17016     0.0
# 17608     1.0
# 18176     2.0
# 18698     3.0
# 19275     4.0
# 19877     5.0
# 20458     6.0
# 21070     7.0
# 21627     8.0
# 22213     9.0
# 22829    10.0
# 23466    11.0
# 24057    12.0
# 24643    13.0
# Name: Year, dtype: float64
# Tim Duncan
# 13551     0.0
# 14096     1.0
# 14607     2.0
# 15103     3.0
# 15643     4.0
# 16129     5.0
# 16647     6.0
# 17234     7.0
# 17806     8.0
# 18351     9.0
# 18889    10.0
# 19504    11.0
# 20069    12.0
# 20681    13.0
# 21262    14.0
# 21825    15.0
# 22436    16.0
# 23038    17.0
# 23652    18.0
# Name: Year, dtype: float64
# Shaquille O'Neal
# Series([], Name: Year, dtype: float64)
# Allen Iverson
# Series([], Name: Year, dtype: float64)
# Ray Allen
# 12846     0.0
# 13420     1.0
# 13965     2.0
# 14475     3.0
# ...

# %%
values
# Out:
# {}

# %%
dfs['name'] = dfs['Player']

# %%
dfp2 = dfp[['name','height']]
dfp2.reset_index()
# Out:
#       index                 name height
# 0         0       Alaa Abdelnaby   6-10
# 1         1      Zaid Abdul-Aziz    6-9
# 2         2  Kareem Abdul-Jabbar    7-2
# 3         3   Mahmoud Abdul-Rauf    6-1
# 4         4    Tariq Abdul-Wahad    6-6
# 5         5  Shareef Abdur-Rahim    6-9
# 6         6        Tom Abernethy    6-7
# 7         7          Forest Able    6-3
# 8         8       John Abramovic    6-3
# 9         9         Alex Abrines    6-6
# 10       10           Alex Acker    6-5
# 11       11         Don Ackerman    6-0
# 12       12           Mark Acres   6-11
# 13       13            Bud Acton    6-6
# 14       14           Quincy Acy    6-7
# 15       15          Alvan Adams    6-9
# 16       16            Don Adams    6-6
# 17       17         George Adams    6-5
# 18       18         Hassan Adams    6-4
# 19       19         Jordan Adams    6-5
# 20       20        Michael Adams   5-10
# 21       21         Steven Adams    7-0
# ...

# %%
df_merge = dfs.set_index('name').join(dfp2.set_index('name'))

# %%
df_merge2 = dfs.set_index('name').join(dfp.set_index('name'))

# %%
df_merge2
# Out:
#                  Year         Player  Pos   Age   Tm     G    GS      MP  \
# name
# A.C. Green     1986.0     A.C. Green   PF  22.0  LAL  82.0   1.0  1542.0
# A.C. Green     1987.0     A.C. Green   PF  23.0  LAL  79.0  72.0  2240.0
# A.C. Green     1988.0     A.C. Green   PF  24.0  LAL  82.0  64.0  2636.0
# A.C. Green     1989.0     A.C. Green   PF  25.0  LAL  82.0  82.0  2510.0
# A.C. Green     1990.0     A.C. Green   PF  26.0  LAL  82.0  82.0  2709.0
# A.C. Green     1991.0     A.C. Green   PF  27.0  LAL  82.0  21.0  2164.0
# A.C. Green     1992.0     A.C. Green   PF  28.0  LAL  82.0  53.0  2902.0
# A.C. Green     1993.0     A.C. Green   PF  29.0  LAL  82.0  55.0  2819.0
# A.C. Green     1994.0     A.C. Green   PF  30.0  PHO  82.0  55.0  2825.0
# A.C. Green     1995.0     A.C. Green   SF  31.0  PHO  82.0  52.0  2687.0
# A.C. Green     1996.0     A.C. Green   SF  32.0  PHO  82.0  36.0  2113.0
# A.C. Green     1997.0     A.C. Green   PF  33.0  TOT  83.0  73.0  2492.0
# ...

# %%
df_merge2['YearInNBA'] = df_merge2.Year - df_merge2.year_start

# %%
df_merge2['PPG'] = df_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-7603c9888e27> in <module>
# ----> 1 df_merge2['PPG'] = df_
#
# NameError: name 'df_' is not defined

# %%
df_merge2
# Out:
#                  Year         Player  Pos   Age   Tm     G    GS      MP  \
# name
# A.C. Green     1986.0     A.C. Green   PF  22.0  LAL  82.0   1.0  1542.0
# A.C. Green     1987.0     A.C. Green   PF  23.0  LAL  79.0  72.0  2240.0
# A.C. Green     1988.0     A.C. Green   PF  24.0  LAL  82.0  64.0  2636.0
# A.C. Green     1989.0     A.C. Green   PF  25.0  LAL  82.0  82.0  2510.0
# A.C. Green     1990.0     A.C. Green   PF  26.0  LAL  82.0  82.0  2709.0
# A.C. Green     1991.0     A.C. Green   PF  27.0  LAL  82.0  21.0  2164.0
# A.C. Green     1992.0     A.C. Green   PF  28.0  LAL  82.0  53.0  2902.0
# A.C. Green     1993.0     A.C. Green   PF  29.0  LAL  82.0  55.0  2819.0
# A.C. Green     1994.0     A.C. Green   PF  30.0  PHO  82.0  55.0  2825.0
# A.C. Green     1995.0     A.C. Green   SF  31.0  PHO  82.0  52.0  2687.0
# A.C. Green     1996.0     A.C. Green   SF  32.0  PHO  82.0  36.0  2113.0
# A.C. Green     1997.0     A.C. Green   PF  33.0  TOT  83.0  73.0  2492.0
# ...

# %%
df_merge.groupby('name').PTS.max()
# Out:
# name
# A.C. Green            1204.0
# A.J. Bramlett            8.0
# A.J. English           886.0
# A.J. Guyton            244.0
# A.J. Hammons            48.0
# A.J. Price             441.0
# A.J. Wynder             12.0
# A.W. Holt                4.0
# Aaron Brooks          1604.0
# Aaron Gordon          1019.0
# Aaron Gray             262.0
# Aaron Harrison          18.0
# Aaron James            973.0
# Aaron McKie            878.0
# Aaron Miles             16.0
# Aaron Swinson           24.0
# Aaron Williams         838.0
# Abdul Jeelani          737.0
# Acie Earl              410.0
# Acie Law               235.0
# Adam Harrington         30.0
# Adam Keefe             620.0
# Adam Morrison          917.0
# Adonal Foyle           440.0
# Adonis Jordan           15.0
# Adonis Thomas           14.0
# Adreian Payne          213.0
# Adrian Branch          498.0
# Adrian Caldwell        110.0
# Adrian Dantley*       2457.0
#                        ...
# Worthy Patterson         7.0
# ...

# %%
mydf = df_merge2[df_merge2.Player.isin(players_studied)]

# %%
mydf['PPG'] = mydf.PTS/mydf.G
# Out:
# /Users/rami/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
mydf.to_csv('data.csv')

# %%
mydf
# Out:
#                      Year             Player Pos   Age   Tm     G    GS  \
# name
# Amar'e Stoudemire  2003.0  Amar'e Stoudemire  PF  20.0  PHO  82.0  71.0
# Amar'e Stoudemire  2004.0  Amar'e Stoudemire  PF  21.0  PHO  55.0  53.0
# Amar'e Stoudemire  2005.0  Amar'e Stoudemire   C  22.0  PHO  80.0  80.0
# Amar'e Stoudemire  2006.0  Amar'e Stoudemire   C  23.0  PHO   3.0   3.0
# Amar'e Stoudemire  2007.0  Amar'e Stoudemire   C  24.0  PHO  82.0  78.0
# Amar'e Stoudemire  2008.0  Amar'e Stoudemire   C  25.0  PHO  79.0  79.0
# Amar'e Stoudemire  2009.0  Amar'e Stoudemire  PF  26.0  PHO  53.0  53.0
# Amar'e Stoudemire  2010.0  Amar'e Stoudemire  PF  27.0  PHO  82.0  82.0
# Amar'e Stoudemire  2011.0  Amar'e Stoudemire   C  28.0  NYK  78.0  78.0
# Amar'e Stoudemire  2012.0  Amar'e Stoudemire  PF  29.0  NYK  47.0  47.0
# Amar'e Stoudemire  2013.0  Amar'e Stoudemire  PF  30.0  NYK  29.0   0.0
# Amar'e Stoudemire  2014.0  Amar'e Stoudemire   C  31.0  NYK  65.0  21.0
# ...
