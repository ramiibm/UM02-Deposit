# %%
import pandas as pd

# %%
dfplayers = pd.read_csv('data/player_data.csv')

# %%
dfplayers.head()
# Out:
#                   name  year_start  year_end position height  weight  \
# 0       Alaa Abdelnaby        1991      1995      F-C   6-10   240.0
# 1      Zaid Abdul-Aziz        1969      1978      C-F    6-9   235.0
# 2  Kareem Abdul-Jabbar        1970      1989        C    7-2   225.0
# 3   Mahmoud Abdul-Rauf        1991      2001        G    6-1   162.0
# 4    Tariq Abdul-Wahad        1998      2003        F    6-6   223.0
#
#          birth_date                                college
# 0     June 24, 1968                        Duke University
# 1     April 7, 1946                  Iowa State University
# 2    April 16, 1947  University of California, Los Angeles
# 3     March 9, 1969             Louisiana State University
# 4  November 3, 1974              San Jose State University

# %%
dfplayers[dfplayers['name']=="Kobe Bryant"].year_start
# Out:
# 528    1997
# Name: year_start, dtype: int64

# %%
dfseasons = pd.read_csv('data/Seasons_Stats.csv', index_col = 0)

# %%
dfseasons.tail()
# Out:
#          Year             Player Pos   Age   Tm     G    GS      MP   PER  \
# 24686  2017.0        Cody Zeller  PF  24.0  CHO  62.0  58.0  1725.0  16.7
# 24687  2017.0       Tyler Zeller   C  27.0  BOS  51.0   5.0   525.0  13.0
# 24688  2017.0  Stephen Zimmerman   C  20.0  ORL  19.0   0.0   108.0   7.3
# 24689  2017.0        Paul Zipser  SF  22.0  CHI  44.0  18.0   843.0   6.9
# 24690  2017.0        Ivica Zubac   C  19.0  LAL  38.0  11.0   609.0  17.0
#
#          TS%  ...    FT%    ORB    DRB    TRB   AST   STL   BLK   TOV     PF  \
# 24686  0.604  ...  0.679  135.0  270.0  405.0  99.0  62.0  58.0  65.0  189.0
# 24687  0.508  ...  0.564   43.0   81.0  124.0  42.0   7.0  21.0  20.0   61.0
# 24688  0.346  ...  0.600   11.0   24.0   35.0   4.0   2.0   5.0   3.0   17.0
# 24689  0.503  ...  0.775   15.0  110.0  125.0  36.0  15.0  16.0  40.0   78.0
# 24690  0.547  ...  0.653   41.0  118.0  159.0  30.0  14.0  33.0  30.0   66.0
#
#          PTS
# 24686  639.0
# 24687  178.0
# 24688   23.0
# ...

# %%
dfkobe = dfseasons[dfseasons['Player']=="Kobe Bryant"]

# %%
dfkobe
# Out:
#          Year       Player Pos   Age   Tm     G    GS      MP   PER    TS%  \
# 12900  1997.0  Kobe Bryant  SG  18.0  LAL  71.0   6.0  1103.0  14.4  0.544
# 13479  1998.0  Kobe Bryant  SG  19.0  LAL  79.0   1.0  2056.0  18.5  0.548
# 14021  1999.0  Kobe Bryant  SG  20.0  LAL  50.0  50.0  1896.0  18.9  0.549
# 14537  2000.0  Kobe Bryant  SG  21.0  LAL  66.0  62.0  2524.0  21.7  0.546
# 15028  2001.0  Kobe Bryant  SG  22.0  LAL  68.0  68.0  2783.0  24.5  0.552
# 15578  2002.0  Kobe Bryant  SG  23.0  LAL  80.0  80.0  3063.0  23.2  0.544
# 16070  2003.0  Kobe Bryant  SG  24.0  LAL  82.0  82.0  3401.0  26.2  0.550
# 16576  2004.0  Kobe Bryant  SG  25.0  LAL  65.0  64.0  2447.0  23.7  0.551
# 17159  2005.0  Kobe Bryant  SG  26.0  LAL  66.0  66.0  2689.0  23.3  0.563
# 17742  2006.0  Kobe Bryant  SG  27.0  LAL  80.0  80.0  3277.0  28.0  0.559
# 18295  2007.0  Kobe Bryant  SG  28.0  LAL  77.0  77.0  3140.0  26.1  0.580
# ...

# %%
dfkobe['PPG'] = dfkobe.PTS/dfkobe.G
# Out:
# /Users/rami/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dfkobe
# Out:
#          Year       Player Pos   Age   Tm     G    GS      MP   PER    TS%  \
# 12900  1997.0  Kobe Bryant  SG  18.0  LAL  71.0   6.0  1103.0  14.4  0.544
# 13479  1998.0  Kobe Bryant  SG  19.0  LAL  79.0   1.0  2056.0  18.5  0.548
# 14021  1999.0  Kobe Bryant  SG  20.0  LAL  50.0  50.0  1896.0  18.9  0.549
# 14537  2000.0  Kobe Bryant  SG  21.0  LAL  66.0  62.0  2524.0  21.7  0.546
# 15028  2001.0  Kobe Bryant  SG  22.0  LAL  68.0  68.0  2783.0  24.5  0.552
# 15578  2002.0  Kobe Bryant  SG  23.0  LAL  80.0  80.0  3063.0  23.2  0.544
# 16070  2003.0  Kobe Bryant  SG  24.0  LAL  82.0  82.0  3401.0  26.2  0.550
# 16576  2004.0  Kobe Bryant  SG  25.0  LAL  65.0  64.0  2447.0  23.7  0.551
# 17159  2005.0  Kobe Bryant  SG  26.0  LAL  66.0  66.0  2689.0  23.3  0.563
# 17742  2006.0  Kobe Bryant  SG  27.0  LAL  80.0  80.0  3277.0  28.0  0.559
# 18295  2007.0  Kobe Bryant  SG  28.0  LAL  77.0  77.0  3140.0  26.1  0.580
# ...

# %%
(dfkobe.Year - float(dfplayers[dfplayers['name']=="Kobe Bryant"].year_start)).astype(int)
# Out:
# 12900     0
# 13479     1
# 14021     2
# 14537     3
# 15028     4
# 15578     5
# 16070     6
# 16576     7
# 17159     8
# 17742     9
# 18295    10
# 18825    11
# 19428    12
# 20006    13
# 20600    14
# 21196    15
# 21757    16
# 22348    17
# 22944    18
# 23586    19
# Name: Year, dtype: int64

# %%
dfkd = df_seasons[df_seasons['Player']=="Kevin Durant"]

# %%
dfkd
# Out:
#          Year        Player Pos   Age   Tm     G    GS      MP   PER    TS%  \
# 18894  2008.0  Kevin Durant  SG  19.0  SEA  80.0  80.0  2768.0  15.8  0.519
# 19506  2009.0  Kevin Durant  SF  20.0  OKC  74.0  74.0  2885.0  20.8  0.577
# 20071  2010.0  Kevin Durant  SF  21.0  OKC  82.0  82.0  3239.0  26.2  0.607
# 20684  2011.0  Kevin Durant  SF  22.0  OKC  78.0  78.0  3038.0  23.6  0.589
# 21264  2012.0  Kevin Durant  SF  23.0  OKC  66.0  66.0  2546.0  26.2  0.610
# 21827  2013.0  Kevin Durant  SF  24.0  OKC  81.0  81.0  3119.0  28.3  0.647
# 22438  2014.0  Kevin Durant  SF  25.0  OKC  81.0  81.0  3122.0  29.8  0.635
# 23040  2015.0  Kevin Durant  SF  26.0  OKC  27.0  27.0   913.0  27.6  0.633
# 23654  2016.0  Kevin Durant  SF  27.0  OKC  72.0  72.0  2578.0  28.2  0.634
# 24239  2017.0  Kevin Durant  SF  28.0  GSW  62.0  62.0  2070.0  27.6  0.651
#
#        ...    FT%    ORB    DRB    TRB    AST    STL    BLK    TOV     PF  \
# ...

# %%
df_seasons[df_seasons['Player']=="Michael Jordan*"]
# Out:
#          Year           Player Pos   Age   Tm     G    GS      MP   PER  \
# 7716   1985.0  Michael Jordan*  SG  21.0  CHI  82.0  82.0  3144.0  25.8
# 8094   1986.0  Michael Jordan*  SG  22.0  CHI  18.0   7.0   451.0  27.5
# 8469   1987.0  Michael Jordan*  SG  23.0  CHI  82.0  82.0  3281.0  29.8
# 8869   1988.0  Michael Jordan*  SG  24.0  CHI  82.0  82.0  3311.0  31.7
# 9297   1989.0  Michael Jordan*  SG  25.0  CHI  81.0  81.0  3255.0  31.1
# 9747   1990.0  Michael Jordan*  SG  26.0  CHI  82.0  82.0  3197.0  31.2
# 10212  1991.0  Michael Jordan*  SG  27.0  CHI  82.0  82.0  3034.0  31.6
# 10666  1992.0  Michael Jordan*  SG  28.0  CHI  80.0  80.0  3102.0  27.7
# 11106  1993.0  Michael Jordan*  SG  29.0  CHI  78.0  78.0  3067.0  29.7
# 12048  1995.0  Michael Jordan*  SG  31.0  CHI  17.0  17.0   668.0  22.1
# 12528  1996.0  Michael Jordan*  SG  32.0  CHI  82.0  82.0  3090.0  29.4
# 13096  1997.0  Michael Jordan*  SG  33.0  CHI  82.0  82.0  3106.0  27.8
# ...
